# %%
#Mean,Median,Mode(Modus)
import numpy as np
from scipy import stats as st

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = np.mean(speed)
y = np.median(speed)
a = st.mode(speed)

print(x)
print(y)
print(a)


speed1 = [99,86,87,88,86,103,87,94,78,77,85,86]

z = np.median(speed1)

print(z)
# Out:
# 89.76923076923077
# 87.0
# ModeResult(mode=np.int64(86), count=np.int64(3))
# 86.5

# %%
#Standar Deviasi
import numpy

speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %%
#Varians
import numpy

speed = [32,111,138,28,59,77,97]

x = numpy.var(speed)

print(x)
# Out:
# 1432.2448979591834

# %%
#Percentile
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print(x)
# Out:
# 43.0

# %%
#Histogram
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)
plt.show()

# %%
#Big Data Distributions
import numpy as np
import matplotlib.pyplot as plt

a = np.random.uniform(0.0, 5.0, 100000)

plt.hist(a, 100)
plt.title("Distribusi Uniform (0.0 - 5.0)")
plt.xlabel("Nilai")
plt.ylabel("Frekuensi")
plt.grid(True)
plt.show()

# %%
#Normal Distribution
import numpy
import matplotlib.pyplot as plt

b = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(b, 100)
plt.show()

# %%
#Three lines to make our compiler able to draw:
import sys
import matplotlib
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
#Random Distribution Scatter Plot
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %%
#Regresi Linier
#Three lines to make our compiler able to draw:
import sys
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
'''
Cek nilai apakah ada hubungan antar data melalui regresi linier (0 = tidak ada
-1 sampai 1 ada)
'''
from scipy import stats
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# -0.758591524376155

# %%
#Predict Future Values
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %%
#Regresi Linier (Bad Fit)
import matplotlib.pyplot as plt
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
#Nilai Regresi Linier (Bad Fit)
import numpy
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# 0.01331814154297491

# %%
# Multiple Regression
import pandas as pd
from sklearn import linear_model

df = pd.read_csv("data.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

# Prediksi CO2 emission untuk mobil dengan berat 2300kg dan volume 1300cm3
input_data = pd.DataFrame([[2300, 1300]], columns=['Weight', 'Volume'])
predictedCO2 = regr.predict(input_data)

print(predictedCO2)
# Out:
# [107.2087328]

# %%
#Coefficient
import pandas
from sklearn import linear_model

df = pandas.read_csv("data.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [0.00755095 0.00780526]

# %%
#Jika nilai x di naikkan
import pandas
from sklearn import linear_model

df = pandas.read_csv("data.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

regr = linear_model.LinearRegression()
regr.fit(X, y)

# Buat DataFrame dengan kolom yang sesuai
input_data = pandas.DataFrame([[3300, 1300]], columns=['Weight', 'Volume'])

# Prediksi
predictedCO2 = regr.predict(input_data)

print(predictedCO2)
# Out:
# [114.75968007]

# %%
#Scale Features
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

df = pandas.read_csv("data.csv")

X = df[['Weight', 'Volume']]

scaledX = scale.fit_transform(X)

print(scaledX)
# Out:
# [[-2.10389253 -1.59336644]
#  [-0.55407235 -1.07190106]
#  [-1.52166278 -1.59336644]
#  [-1.78973979 -1.85409913]
#  [-0.63784641 -0.28970299]
#  [-1.52166278 -1.59336644]
#  [-0.76769621 -0.55043568]
#  [ 0.3046118  -0.28970299]
#  [-0.7551301  -0.28970299]
#  [-0.59595938 -0.0289703 ]
#  [-1.30803892 -1.33263375]
#  [-1.26615189 -0.81116837]
#  [-0.7551301  -1.59336644]
#  [-0.16871166 -0.0289703 ]
#  [ 0.14125238 -0.0289703 ]
#  [ 0.15800719 -0.0289703 ]
#  [ 0.3046118  -0.0289703 ]
#  [-0.05142797  1.53542584]
#  [-0.72580918 -0.0289703 ]
#  [ 0.14962979  1.01396046]
#  [ 1.2219378  -0.0289703 ]
#  [ 0.5685001   1.01396046]
#  [ 0.3046118   1.27469315]
#  [ 0.51404696 -0.0289703 ]
#  [ 0.51404696  1.01396046]
#  [ 0.72348212 -0.28970299]
#  [ 0.8281997   1.01396046]
#  [ 1.81254495  1.01396046]
#  [ 0.96642691 -0.0289703 ]
#  [ 1.72877089  1.01396046]
#  [ 1.30990057  1.27469315]
#  [ 1.90050772  1.01396046]
#  [-0.23991961 -0.0289703 ]
#  [ 0.40932938 -0.0289703 ]
# ...

# %%
#Training and Test Machine Learning (New Dataset)
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

plt.scatter(x, y)
plt.show()

# %%
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

# %%
plt.scatter(train_x, train_y)
plt.show()

# %%
plt.scatter(test_x, test_y)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

myline = numpy.linspace(0, 6, 100)

plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
#Polynomial Regression
import numpy
from sklearn.metrics import r2_score
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

r2 = r2_score(train_y, mymodel(train_x))

print(r2)
# Out:
# 0.79886455446298

# %%
import numpy
from sklearn.metrics import r2_score
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

r2 = r2_score(test_y, mymodel(test_x))

print(r2)
# Out:
# 0.8086921460343566

# %%
print(mymodel(5))
# Out:
# 22.8796259181172
